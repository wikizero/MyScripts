# %%
import records
import pandas as pd

db = records.Database('mysql://root:root@39.108.141.110/world')
rows = db.query('select * from info')
df = rows.export('df').drop(['url','info_id', 'sold_date'], axis=1)
df
# Out:
#       release_date                 title  sold_times   price account_type  \
# 0       2017-03-20             【22级】朕的江山           0   330.0         UC帐号
# 1       2017-03-26     【14级】四橙刘备双奶五星双糜双马           2    30.0         UC帐号
# 2       2017-04-06  【20级】有四奶的郡守号了，在郡守玩的开           0    99.0         UC帐号
# 3       2017-04-11  【29级】10万魂左右太史慈满觉诸葛1觉           0   550.0         UC帐号
# 4       2017-04-12       【22级】郡守区强力号觉醒典韦           1   400.0         UC帐号
# 5       2017-04-19    【23级】5.5万魂觉醒诸葛赵云4星           0  1000.0         UC帐号
# 6       2017-04-20         【17级】关羽赵云胃炎马5           0   200.0         UC帐号
# 7       2017-04-23         【11级】关羽张飞差刘备了           3    50.0         UC帐号
# 8       2017-04-23     【16级】鲁肃孙尚香马超 许绪县令           2    50.0         UC帐号
# 9       2017-04-25  【16级】16级别的县令甩了！自己看图。           0    27.0         百度帐号
# 10      2017-04-25             【20级】值得拥有           0    60.0         华为帐号
# 11      2017-05-03    【17级】刘关猪赵黄姜五奶郡守号看图           1    60.0        360帐号
# ...

# %%
df.groupby('status').size()
# Out:
# status
# on-sale     10807
# remove         71
# sold-out      199
# dtype: int64

# %%
sold_df = df[df.status == 'sold-out']

# %%
sold_df.price.sum()  # 总交易额
# Out:
# 60766.540000000008

# %%
print(sold_df.release_date.min()) 
print(sold_df.release_date.max())
# Out:
# 2017-06-16
# 2018-03-30

# %%
sold_df.groupby('account_type').size()
# Out:
# account_type
# OPPO帐号       3
# UC帐号       170
# vivo帐号       3
# 华为帐号         1
# 安智帐号         1
# 小米帐号         2
# 游戏fan帐号     15
# 百度帐号         1
# dtype: int64

# %%
sold_df.sort_values('level')
# Out:
#       release_date                 title  sold_times    price account_type  \
# 3867    2017-09-30    【7级】7级亭长号，退游了，低价卖了           0     10.0         UC帐号
# 3413    2017-09-26           【7级】双糜5紫开局号           0     12.0         UC帐号
# 3402    2017-09-25       【7级】7级初始双糜躲闪可世界           0     10.0         UC帐号
# 3548    2017-09-26          【7级】开局号 已灭一人           0     10.0         UC帐号
# 3380    2017-09-25          【7级】双马糜夫人开局号           0     15.0         UC帐号
# 2004    2017-09-09   【7级】可发世界频道，有元宝，任务已做           0     10.0         UC帐号
# 1975    2017-09-09   【7级】可发世界频道，有元宝，任务已做           0     10.0         UC帐号
# 1973    2017-09-09   【7级】可发世界频道，有元宝，任务已做           0     10.0         UC帐号
# 3378    2017-09-25          【7级】双马糜夫人开局号           0     15.0         UC帐号
# 1094    2017-08-20            【7级】糜夫人开局号           0     10.0         UC帐号
# 3665    2017-09-27           【7级】7级初始可世界           0     10.0         UC帐号
# ...

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure

# output_file("bar_basic.html")

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="943c3343-7e2c-4d00-a2e9-7096c7898f13">Loading BokehJS ...</span>
#     </div>

# %%
# %matplotlib inline
sold_df.groupby('price').size().sort_values()
# Out:
# price
# 22000.00     1
# 115.00       1
# 119.00       1
# 125.00       1
# 130.00       1
# 131.00       1
# 350.00       1
# 158.00       1
# 340.00       1
# 2650.00      1
# 188.88       1
# 330.00       1
# 208.00       1
# 210.00       1
# 310.00       1
# 229.00       1
# 230.00       1
# 235.00       1
# 240.00       1
# 248.00       1
# 250.00       1
# 272.00       1
# 299.00       1
# 550.00       1
# 400.00       1
# 95.00        1
# 2500.00      1
# 1800.00      1
# 16.00        1
# 18.00        1
#             ..
# 288.00       1
# 333.00       2
# 380.00       2
# 390.00       2
# 600.00       2
# 180.00       2
# 99.00        2
# 30.00        2
# 70.00        2
# 280.00       2
# 25.00        2
# 109.00       2
# 170.00       2
# 160.00       3
# 40.00        3
# 220.00       3
# 500.00       4
# 80.00        4
# 150.00       4
# 120.00       5
# 100.00       5
# 12.00        5
# 35.00        5
# 300.00       6
# 110.00       6
# 200.00       6
# 50.00        6
# ...

# %%
sold_df.sort_values(by='release_date', ascending=False)
# Out:
#       release_date                 title  sold_times    price account_type  \
# 11045   2018-04-05      【42级】26万魂陈宫专属3名马           1   213.00         UC帐号
# 10974   2018-04-03         【39级】州牧5满号2专属           0   180.00         小米帐号
# 10947   2018-04-02          【39级】25万五满州牧           2   500.00         UC帐号
# 10884   2018-03-30             【29级】九万刺史           9    40.00      游戏fan帐号
# 10841   2018-03-27          【38级】朕的江山4满号           0    50.00       OPPO帐号
# 10833   2018-03-27             【38级】17万魂           1   120.00         UC帐号
# 10805   2018-03-25         【40级】朕的江山九游账号           0   500.00         UC帐号
# 10798   2018-03-25             【39级】朕的江山           0  2500.00         UC帐号
# 10718   2018-03-21    【39级】22万魂6000策要的快抢           1   229.00         UC帐号
# 10492   2018-03-11             【29级】看好再买           1   150.00         UC帐号
# 10418   2018-03-06      【39级】30多万魂州牧许褚专属           2  1000.00         UC帐号
# ...

# %%
# %matplotlib inline
sold_df = sold_df.assign(dates=sold_df.release_date.str.extract(r'(\d+-\d+)', expand=True))
sold_df.groupby(by='dates').sum()['price'].plot.line()

# %%
df = df.assign(dates=df.release_date.str.extract(r'(\d+-\d+)', expand=True))
df.groupby(by='dates').sum()['price'].plot.line()

# %%
df.groupby('bind_info').size().sort_values()[-8:]
# Out:
# bind_info
# 密保手机,密保问题      88
# 密保邮箱          104
# 密保问题          104
# 密保手机,密保邮箱     175
# 身份证           369
# 密保手机,身份证      465
# 密保手机         3563
# 无绑定          5715
# dtype: int64

# %%
df.groupby('level').size().sort_values()[-20:]
# Out:
# level
# 21     141
# 26     141
# 23     142
# 34     160
# 25     160
# 36     165
# 27     191
# 28     234
# 11     238
# 40     259
# 9      283
# 17     439
# 7      444
# 35     491
# 39     587
# 13     629
# 8     1036
# 10    1067
# 22    1154
# 29    1207
# dtype: int64

# %%
dfs = pd.DataFrame({'foo': ['one','one','one','two','two','two'],
                       'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                       'baz': [1, 2, 3, 4, 5, 6]})

# %%
dfs
# Out:
#   bar  baz  foo
# 0   A    1  one
# 1   B    2  one
# 2   C    3  one
# 3   A    4  two
# 4   B    5  two
# 5   C    6  two

# %%
dfs.pivot(index='baz', columns='bar')
# Out:
#       foo
# bar     A     B     C
# baz
# 1     one  None  None
# 2    None   one  None
# 3    None  None   one
# 4     two  None  None
# 5    None   two  None
# 6    None  None   two

# %%
dir(dfs)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
dfs = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

# %%
dfs
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
dfs.stack()
# Out:
# 0  A    a
#    B    1
#    C    2
# 1  A    b
#    B    3
#    C    4
# 2  A    c
#    B    5
#    C    6
# dtype: object
